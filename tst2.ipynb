# %%
import pandas as pd
import numpy as np

# %%
Energy = pd.read_excel('/Users/indurangatheshan/Desktop/coursera/Energy Indicators.xls',skiprows=17,skipfooter=38)

# %%
Energy = Energy.drop(columns=Energy.columns[:2])
Energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
Energy['Energy Supply'] = Energy['Energy Supply'] *1000000
Energy.replace('...',np.nan, inplace=True)
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/535971123.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Energy.replace('...',np.nan, inplace=True)

# %%
Energy['Country'] = Energy['Country'].str.replace(r' \(.*\)', '', regex=True)  # Remove parentheses
Energy['Country'] = Energy['Country'].str.replace(r'\d+', '', regex=True)  # Remove numeric digits

# %%
Energy['Country']  = Energy['Country'].replace({
    "Republic of Korea": "South Korea", "United States of America": "United States",
    "United Kingdom of Great Britain and Northern Ireland": "United Kingdom", 
    "China, Hong Kong Special Administrative Region": "Hong Kong"
})

# %%
GDP = pd.read_csv('/Users/indurangatheshan/Desktop/coursera/world_bank.csv',skiprows=4)

# %%
GDP.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1      Andorra          AND  GDP at market prices (constant 2010 US$)
# 2  Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3       Angola          AGO  GDP at market prices (constant 2010 US$)
# 4      Albania          ALB  GDP at market prices (constant 2010 US$)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...          2006  \
# 0  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 1  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.018196e+09
# 2  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.030523e+10
# 3  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.581103e+10
# 4  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.771760e+09
#
#            2007          2008          2009          2010          2011  \
# ...

# %%
GDP['Country Name'] = GDP['Country Name'].replace({
    "Korea, Rep.": "South Korea",  "Iran, Islamic Rep.": "Iran",
    "Hong Kong SAR, China": "Hong Kong"
})

# %%
years = [str(year) for year in range(2006,2016)]
GDP = GDP[['Country Name'] + years]

# %%
GDP.head()
# Out:
#   Country Name          2006          2007          2008          2009  \
# 0        Aruba           NaN           NaN           NaN           NaN
# 1      Andorra  4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# 2  Afghanistan  1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# 3       Angola  5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# 4      Albania  9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
#
#            2010          2011          2012          2013          2014  \
# 0  2.467704e+09           NaN           NaN           NaN           NaN
# 1  3.346317e+09  3.185605e+09  3.129538e+09  3.127550e+09           NaN
# 2  1.593680e+10  1.691113e+10  1.935220e+10  1.973134e+10  1.999032e+10
# 3  8.247091e+10  8.570262e+10  9.012096e+10  9.626143e+10  1.008863e+11
# 4  1.192695e+10  1.223109e+10  1.240477e+10  1.254247e+10  1.279331e+10
#
#            2015
# 0           NaN
# 1           NaN
# 2  2.029415e+10
# 3  1.039106e+11
# 4  1.312082e+10

# %%
ScimEn = pd.read_excel('/Users/indurangatheshan/Desktop/coursera/scimagojr-3.xlsx')

# %%
ScimEn = ScimEn[ScimEn['Rank'] <=15 ]

# %%
ScimEn.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# 3           37874                    9.84      139
# 4           12422                    1.85       57

# %%
ScimEn['Country'] = ScimEn['Country'].str.strip()
Energy['Country'] = Energy['Country'].str.strip()

# %%
rows_before = len(ScimEn) + len(Energy) + len(GDP)

# %%
merged = pd.merge(ScimEn,Energy , how='inner',left_on='Country',right_on='Country')
final_df = pd.merge(merged,GDP,how='inner', left_on='Country',right_on='Country Name')

# %%
final_df.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index Energy Supply  \
# 0          411683                    4.70      138  127191000000
# 1          265436                    8.20      230   90838000000
# 2           61554                    7.31      134   18984000000
# 3           37874                    9.84      139    7920000000
# 4           12422                    1.85       57   30709000000
#
#    Energy Supply per Capita  ...          2006          2007          2008  \
# 0                      93.0  ...  3.992331e+12  4.559041e+12  4.997775e+12
# ...

# %%
final_df.set_index('Country',inplace=True)

# %%
final_df = final_df.sort_values(by='Rank')

# %%
columns = ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable'] + years
final_df = final_df[columns]

# %%
final_df
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
final_df = final_df.iloc[:15]

# %%
final_df
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
years = [str(year) for year in range(2006,2016)]
years
# Out:
# ['2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015']

# %%
final_df['avgGDP']= final_df[years].mean(axis=1)
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/4076086348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['avgGDP']= final_df[years].mean(axis=1)

# %%
sorted_df = final_df.sort_values(by='avgGDP' , ascending=False)

# %%
sixth_country = sorted_df.iloc[5]

# %%
gdp_change = sixth_country['2015']-sixth_country['2006']

# %%
print("GDP in 2006:", sixth_country['2006'])
print("GDP in 2015:", sixth_country['2015'])
print("GDP Change:", gdp_change)

print(gdp_change)
# Out:
# GDP in 2006: 2419630700401.73
# GDP in 2015: 2666333396477.13
# GDP Change: 246702696075.3999
# 246702696075.3999

# %%
max_ren_country = final_df['% Renewable'].idxmax()

# %%
max_ren_precentage =final_df.loc[max_ren_country,'% Renewable']

# %%
print (max_ren_country ,max_ren_precentage )
# Out:
# Brazil 69.64803

# %%
final_df['Self_citations_Ratio'] = final_df['Self-citations']/final_df['Citations']
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/800961946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Self_citations_Ratio'] = final_df['Self-citations']/final_df['Citations']

# %%
max_ration_country = final_df['Self_citations_Ratio'].idxmax()

# %%
max_ratio = final_df.loc[max_ration_country,'Self_citations_Ratio']

# %%
max_ratio
# Out:
# np.float64(0.6893126179389422)

# %%
final_df['Population'] = final_df['Energy Supply']/final_df['Energy Supply per Capita']
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/1585953731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Population'] = final_df['Energy Supply']/final_df['Energy Supply per Capita']

# %%
final_df['Citable docs per Capita']= final_df['Citable documents']/ final_df['Population']
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/3628426015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Citable docs per Capita']= final_df['Citable documents']/ final_df['Population']

# %%
correlation = final_df['Citable docs per Capita'].corr(final_df['Energy Supply per Capita'])

# %%
correlation
# Out:
# np.float64(0.7940010435442945)

# %%
median_renewable = final_df['% Renewable'].median()

# %%
final_df['HighRenew'] = final_df['% Renewable'].apply(lambda x: 1 if x >=median_renewable else 0)
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/3759684444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['HighRenew'] = final_df['% Renewable'].apply(lambda x: 1 if x >=median_renewable else 0)

# %%
df_sorted =final_df.sort_values(by='Rank')

# %%
df_sorted['HighRenew']
# Out:
# Country
# China                 1
# United States         0
# Japan                 0
# United Kingdom        0
# Russian Federation    1
# Canada                1
# Germany               1
# India                 0
# France                1
# South Korea           0
# Italy                 1
# Spain                 1
# Iran                  0
# Australia             0
# Brazil                1
# Name: HighRenew, dtype: int64

# %%
ContinentDict = {
        'China': 'Asia',
        'United States': 'North America',
        'Japan': 'Asia',
        'United Kingdom': 'Europe',
        'Russian Federation': 'Europe',
        'Canada': 'North America',
        'Germany': 'Europe',
        'India': 'Asia',
        'France': 'Europe',
        'South Korea': 'Asia',
        'Italy': 'Europe',
        'Spain': 'Europe',
        'Iran': 'Asia',
        'Australia': 'Australia',
        'Brazil': 'South America'
    }

# %%
final_df['Continent'] = final_df.index.map(ContinentDict)
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/3102634378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Continent'] = final_df.index.map(ContinentDict)

# %%
final_df['Population'] = final_df['Energy Supply'] / final_df['Energy Supply per Capita']
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/3434883618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Population'] = final_df['Energy Supply'] / final_df['Energy Supply per Capita']

# %%
grouped = final_df.groupby('Continent')['Population'].agg(['size', 'sum', 'mean', 'std'])

# %%
grouped
# Out:
#                size               sum              mean           std
# Continent
# Asia              5   2898666386.6106   579733277.32212  6.790979e+08
# Australia         1   23316017.316017   23316017.316017           NaN
# Europe            6  457929667.216372   76321611.202729  3.464767e+07
# North America     2   352855249.48025  176427624.740125  1.996696e+08
# South America     1  205915254.237288  205915254.237288           NaN

# %%
final_df['Continent'] = final_df.index.map(ContinentDict)
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/3102634378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Continent'] = final_df.index.map(ContinentDict)

# %%
final_df['% Renewable bin'] = pd.cut(final_df['% Renewable'],bins=5)
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/1489109362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['% Renewable bin'] = pd.cut(final_df['% Renewable'],bins=5)

# %%
grouped = final_df.groupby(['Continent', '% Renewable bin']).size()
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/3350788655.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = final_df.groupby(['Continent', '% Renewable bin']).size()

# %%
grouped = grouped[grouped > 0] 
grouped
# Out:
# Continent      % Renewable bin
# Asia           (2.212, 15.753]     4
#                (15.753, 29.227]    1
# Australia      (2.212, 15.753]     1
# Europe         (2.212, 15.753]     1
#                (15.753, 29.227]    3
#                (29.227, 42.701]    2
# North America  (2.212, 15.753]     1
#                (56.174, 69.648]    1
# South America  (56.174, 69.648]    1
# dtype: int64

# %%
len(grouped)
# Out:
# 9

# %%
final_df['PopEst'] = final_df['Energy Supply'] / final_df['Energy Supply per Capita']
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/3019343267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['PopEst'] = final_df['Energy Supply'] / final_df['Energy Supply per Capita']

# %%
final_df['PopEst'] = final_df['PopEst'].apply(lambda x: f"{x:,.2f}")
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/623330284.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['PopEst'] = final_df['PopEst'].apply(lambda x: f"{x:,.2f}")

# %%
print(final_df['PopEst'])
# Out:
# Country
# China                 1,367,645,161.29
# United States           317,615,384.62
# Japan                   127,409,395.97
# United Kingdom           63,870,967.74
# Russian Federation      143,500,000.00
# Canada                   35,239,864.86
# Germany                  80,369,696.97
# India                 1,276,730,769.23
# France                   63,837,349.40
# South Korea              49,805,429.86
# Italy                    59,908,256.88
# Spain                    46,443,396.23
# Iran                     77,075,630.25
# Australia                23,316,017.32
# Brazil                  205,915,254.24
# Name: PopEst, dtype: object

# %%
len(final_df['PopEst'])
# Out:
# 15

# %%
def answer_twelve():
    # Reuse the merged DataFrame from answer_one
    # Map countries to continents
    ContinentDict = {
        'China': 'Asia',
        'United States': 'North America',
        'Japan': 'Asia',
        'United Kingdom': 'Europe',
        'Russian Federation': 'Europe',
        'Canada': 'North America',
        'Germany': 'Europe',
        'India': 'Asia',
        'France': 'Europe',
        'South Korea': 'Asia',
        'Italy': 'Europe',
        'Spain': 'Europe',
        'Iran': 'Asia',
        'Australia': 'Australia',
        'Brazil': 'South America'
    }

    # Add a Continent column to the DataFrame
    final_df['Continent'] = final_df.index.map(ContinentDict)

    # Create 5 bins for % Renewable
    final_df['% Renewable bin'] = pd.cut(final_df['% Renewable'], bins=5)

    # Group by Continent and % Renewable bin, and count the number of countries in each group
    grouped = final_df.groupby(['Continent', '% Renewable bin']).size()

    # Create a MultiIndex with all possible combinations of Continent and % Renewable bin
    continents = final_df['Continent'].unique()
    renewable_bins = pd.cut(final_df['% Renewable'], bins=5).unique()
    multi_index = pd.MultiIndex.from_product([continents, renewable_bins], names=['Continent', '% Renewable bin'])

    # Reindex the grouped Series to include all combinations
    grouped = grouped.reindex(multi_index, fill_value=0)

    # Remove groups with no countries
    grouped = grouped[grouped > 0]

    # Return the result as a Series
    return grouped

# %%
answer_twelve()
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/2836768551.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Continent'] = final_df.index.map(ContinentDict)
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/2836768551.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['% Renewable bin'] = pd.cut(final_df['% Renewable'], bins=5)
# ...

# %%
len(answer_twelve())
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/2836768551.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Continent'] = final_df.index.map(ContinentDict)
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_1477/2836768551.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['% Renewable bin'] = pd.cut(final_df['% Renewable'], bins=5)
# ...
