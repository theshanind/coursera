# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 
                       'ok', 'ok', 'ok', 'poor', 'poor'],
               columns=["Grades"])

# %%
df.dtypes
# Out:
# Grades    object
# dtype: object

# %%
df['Grades'].astype('category')
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): ['A', 'A+', 'A-', 'B', ..., 'C+', 'C-', 'D', 'D+']

# %%
my_categories = pd.CategoricalDtype(
    categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
    ordered=True
)

# %%
df['Grades'] = df['Grades'].astype(my_categories)

# %%
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df = pd.read_csv('/Users/indurangatheshan/Desktop/coursera/census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df= df[df['SUMLEV']==50]

# %%
df= df.set_index('SUMLEV').groupby(level=0)['CENSUS2010POP'].agg(np.average)

# %%
df.head(5)
# Out:
# SUMLEV
# 50    98262.035646
# Name: CENSUS2010POP, dtype: float64

# %%
bin_data = pd.cut(df,bins =10)

# %%
bin_data.head()
# Out:
# SUMLEV
# 50    (98242.383, 98262.036]
# Name: CENSUS2010POP, dtype: category
# Categories (10, interval[float64, right]): [(98163.774, 98183.426] < (98183.426, 98203.078] < (98203.078, 98222.731] < (98222.731, 98242.383] ... (98281.688, 98301.34] < (98301.34, 98320.993] < (98320.993, 98340.645] < (98340.645, 98360.298]]

# %%
df = pd.read_csv('cwurData.csv')

# %%
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
def create_category(ranking):
    # Since the rank is just an integer, I'll just do a bunch of if/elif statements
    if (ranking >= 1) & (ranking <= 100):
        return "First Tier Top Unversity"
    elif (ranking >= 101) & (ranking <= 200):
        return "Second Tier Top Unversity"
    elif (ranking >= 201) & (ranking <= 300):
        return "Third Tier Top Unversity"
    return "Other Top Unversity"

# %%
df['Rank_level'] = df['world_rank'].apply(lambda x:create_category(x))
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year  \
# ...

# %%
df.pivot_table(index='country', values='score',columns='Rank_level',aggfunc=[np.mean]).head()
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_6812/677936044.py:1: FutureWarning: The provided callable <function mean at 0x1090a8720> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.pivot_table(index='country', values='score',columns='Rank_level',aggfunc=[np.mean]).head()
#                                mean                      \
# Rank_level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
# Austria                         NaN           44.864286
# Belgium                     51.8750           45.081000
# Brazil                          NaN           44.499706
#
#
# Rank_level Second Tier Top Unversity Third Tier Top Unversity
# country
# Argentina                        NaN                      NaN
# ...

# %%
df.pivot_table(index='country', values='score',columns='Rank_level',aggfunc=[np.mean,np.max],margins=True).head()
# Out:
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_6812/1700195431.py:1: FutureWarning: The provided callable <function mean at 0x1090a8720> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.pivot_table(index='country', values='score',columns='Rank_level',aggfunc=[np.mean,np.max],margins=True).head()
# /var/folders/qr/sh2mj8fx10x2gvjt8rm16skc0000gn/T/ipykernel_6812/1700195431.py:1: FutureWarning: The provided callable <function mean at 0x1090a8720> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.pivot_table(index='country', values='score',columns='Rank_level',aggfunc=[np.mean,np.max],margins=True).head()
# ...

# %%
day_of_week = pd.Timestamp(1023 ,9,4,0,1).isoweekday()

# %%
print(day_of_week)
# Out:
# 4
